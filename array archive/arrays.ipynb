# %% [markdown]
# ## Importando as bibliotecas usadas no código

# %%
import numpy as np
import matplotlib.pyplot as plt
import time

# %% [markdown]
# ## Definindo as funções usadas no código

# %%
# Definindo a função bubble sort sem lib (obrigatório)
def bubble_sort(arr):
    lista = np.array(arr)
    n = len(lista)
    for i in range(n):
        for j in range(0, n - i - 1):
            if lista[j] > lista[j + 1]:
                lista[j], lista[j + 1] = lista[j + 1], lista[j]

# %%
def selection_sort(arr):
    lista = np.array(arr.copy())
    n  = len(lista)
    for j in range(n-1):
        min_index = j
        for i in range(j, n):
            if lista[i] < lista[min_index]:
                min_index = i
        lista[j], lista[min_index] = lista[min_index], lista[j]

# %%
def insertion_sort(arr):
    lista = np.array(arr.copy())
    n = len(lista)
    for i in range(n):
        cur = lista[i]
        j = i - 1
        while j >= 0 and lista[j] > cur:
            lista[j+1], lista[j] = lista[j], cur
            j -= 1
    return lista

# %%
def shell_sort(arr):
    lista = np.array(arr.copy())
    n = len(lista)
    gap = n // 2
    while gap >= 1:
        for i in range(n):
            cur = lista[i]
            j = i - gap
            while j >= 0 and lista[j] > cur:
                lista[j+gap], lista[j] = lista[j], cur
                j-= gap
        print(lista)
        gap //= 2

# %%
def quick_sort(arr):
    lista = arr.copy()
    n = len(lista)
    if len(lista) <= 1:
        return np.array(lista)
    else:
        pivo = lista[n // 2]
        menores = [x for x in lista if x < pivo]
        iguais = [x for x in lista if x == pivo]
        maiores = [x for x in lista if x > pivo]
        return np.hstack([quick_sort(menores), iguais, quick_sort(maiores)]).astype(np.int32)

# %%
def merge_sort(arr, inicio=0, fim=None):
    lista = arr
    if fim is None:
        fim = len(lista)
    if (fim - inicio) > 1:
        meio = (inicio + fim) // 2
        merge_sort(arr, inicio, meio)
        merge_sort(arr, meio, fim)
        merge(lista, inicio, meio, fim)
    return lista

def merge(arr, inicio, meio, fim):
    lista = arr
    esquerda = lista[inicio:meio].copy()
    direita = lista[meio:fim].copy()
    i = 0
    j = 0 
    # i para esquerda j para direita
    for k in range(inicio, fim):
        if i >= len(esquerda):
            lista[k] = direita[j]
            j += 1
        elif j >= len(direita):
            lista[k] = esquerda[i]
            i += 1
        elif esquerda[i] <= direita[j]:
            lista[k] = esquerda[i]
            i += 1
        elif direita[j] < esquerda[i]: #podia ser else, mas quis ilustrar melhor a condição
            lista[k] = direita[j]
            j += 1

# %%
# Definindo as função de retorno dos tempo que o array levou a ser ordenado em cada método
def tempo_ordenaçao_bs(lista):
    start_time = time.time()
    bubble_sort(lista.copy())
    end_time = time.time()
    total_time = end_time - start_time
    return total_time

def tempo_ordenaçao_ss(lista):
    start_time = time.time()
    selection_sort(lista.copy())
    end_time = time.time()
    total_time = end_time - start_time
    return total_time

def tempo_ordenaçao_ins(lista):
    start_time = time.time()
    insertion_sort(lista.copy())
    end_time = time.time()
    total_time = end_time - start_time
    return total_time

def tempo_ordenaçao_sh(lista):
    start_time = time.time()
    shell_sort(lista.copy())
    end_time = time.time()
    total_time = end_time - start_time
    return total_time

def tempo_ordenaçao_qs(lista):
    start_time = time.time()
    quick_sort(lista.copy())
    end_time = time.time()
    total_time = end_time - start_time
    return total_time

def tempo_ordenaçao_ms(lista):
    start_time = time.time()
    merge_sort(lista.copy())
    end_time = time.time()
    total_time = end_time - start_time
    return total_time

# %% [markdown]
# ## Definindo os arrays

# %%
# N = 1k
arr1_1k = np.random.randint(1,1001,1000)
arr2_1k = np.random.randint(1,1001,1000)
arr3_1k = np.random.randint(1,1001,1000)
arr_wc_1k = np.sort(arr1_1k.copy())[::-1]

# N = 5k
arr1_5k = np.random.randint(1,1001,5000)
arr2_5k = np.random.randint(1,1001,5000)
arr3_5k = np.random.randint(1,1001,5000)
arr_wc_5k = np.sort(arr1_5k.copy())[::-1]

# N = 10k
arr1_10k = np.random.randint(1,1001,10000)
arr2_10k = np.random.randint(1,1001,10000)
arr3_10k = np.random.randint(1,1001,10000)
arr_wc_10k = np.sort(arr1_10k.copy())[::-1]

# N = 20k
arr1_20k = np.random.randint(1,1001,20000)
arr2_20k = np.random.randint(1,1001,20000)
arr3_20k = np.random.randint(1,1001,20000)
arr_wc_20k = np.sort(arr1_20k.copy())[::-1]

# N = 30k
arr1_30k = np.random.randint(1,1001,30000)
arr2_30k = np.random.randint(1,1001,30000)
arr3_30k = np.random.randint(1,1001,30000)
arr_wc_30k = np.sort(arr1_30k.copy())[::-1]


# N = 40k
arr1_40k = np.random.randint(1,1001,40000)
arr2_40k = np.random.randint(1,1001,40000)
arr3_40k = np.random.randint(1,1001,40000)
arr_wc_40k = np.sort(arr1_40k.copy())[::-1]

# N = 50k
arr1_50k = np.random.randint(1,1001,50000)
arr2_50k = np.random.randint(1,1001,50000)
arr3_50k = np.random.randint(1,1001,50000)
arr_wc_50k = np.sort(arr1_50k.copy())[::-1]

# %% [markdown]
# # `Bubble Sort`

# %% [markdown]
# ## 1. Calculando os tempos de ordenação

# %%
# Pegando o tempo de ordenação dos 4 arrays
time_arr1_1k_bs =  tempo_ordenaçao_bs(arr1_1k)
print(f"Tempo do primeiro array de 1k: {time_arr1_1k_bs} segundos")
time_arr2_1k_bs = tempo_ordenaçao_bs(arr2_1k)
print(f"Tempo do primeiro array de 1k: {time_arr2_1k_bs} segundos")
time_arr3_1k_bs = tempo_ordenaçao_bs(arr3_1k)
print(f"Tempo do primeiro array de 1k: {time_arr3_1k_bs} segundos")
time_wc_1k_bs = tempo_ordenaçao_bs(arr_wc_1k)
print(f"Tempo do primeiro array de 1k: {time_wc_1k_bs} segundos")
# Out:
# Tempo do primeiro array de 1k: 0.1879127025604248 segundos
# Tempo do primeiro array de 1k: 0.18312311172485352 segundos
# Tempo do primeiro array de 1k: 0.18586373329162598 segundos
# Tempo do primeiro array de 1k: 0.27195119857788086 segundos

# %%
# Fazendo uma média dos 3 casos dos arrays aleatórios
mean_arr_1k_bs = (time_arr1_1k_bs + time_arr2_1k_bs + time_arr3_1k_bs)/3
list_arr_1k_bs = np.array([time_arr1_1k_bs, time_arr2_1k_bs, time_arr3_1k_bs, time_wc_1k_bs, mean_arr_1k_bs])
print(f"Tempo médio de ordenação dos arrays de 1k: {mean_arr_1k_bs} segundos.")
# Out:
# Tempo médio de ordenação dos arrays de 1k: 0.18563318252563477 segundos.

# %%
time_arr1_5k_bs =  tempo_ordenaçao_bs(arr1_5k.copy())
print(f"Tempo do primeiro array de 5k: {time_arr1_5k_bs} segundos.")
time_arr2_5k_bs = tempo_ordenaçao_bs(arr2_5k.copy())
print(f"Tempo do primeiro array de 5k: {time_arr2_5k_bs} segundos.")
time_arr3_5k_bs = tempo_ordenaçao_bs(arr3_5k.copy())
print(f"Tempo do primeiro array de 5k: {time_arr3_5k_bs} segundos.")
time_wc_5k_bs = tempo_ordenaçao_bs(arr_wc_5k.copy())
print(f"Tempo do primeiro array de 5k: {time_wc_5k_bs} segundos.")
# Out:
# Tempo do primeiro array de 5k: 4.663098335266113 segundos.
# Tempo do primeiro array de 5k: 4.694922208786011 segundos.
# Tempo do primeiro array de 5k: 4.610650539398193 segundos.
# Tempo do primeiro array de 5k: 6.812740087509155 segundos.

# %%
mean_arr_5k_bs = (time_arr1_5k_bs + time_arr2_5k_bs + time_arr3_5k_bs)/3
list_arr_5k_bs = np.array([time_arr1_5k_bs, time_arr2_5k_bs, time_arr3_5k_bs, time_wc_5k_bs, mean_arr_5k_bs])
print(f"Tempo médio de ordenação dos arrays de 5k {mean_arr_5k_bs} segundos.")
# Out:
# Tempo médio de ordenação dos arrays de 5k 4.656223694483439 segundos.

# %%
time_arr1_10k_bs =  tempo_ordenaçao_bs(arr1_10k.copy())
print(f"Tempo do primeiro array de 10k: {time_arr1_10k_bs} segundos.")
time_arr2_10k_bs = tempo_ordenaçao_bs(arr2_10k.copy())
print(f"Tempo do primeiro array de 10k: {time_arr2_10k_bs} segundos.")
time_arr3_10k_bs = tempo_ordenaçao_bs(arr3_10k.copy())
print(f"Tempo do primeiro array de 10k: {time_arr3_10k_bs} segundos.")
time_wc_10k_bs = tempo_ordenaçao_bs(arr_wc_10k.copy())
print(f"Tempo do primeiro array de 10k: {time_wc_10k_bs} segundos.")
# Out:
# Tempo do primeiro array de 10k: 18.67705726623535 segundos.
# Tempo do primeiro array de 10k: 18.453655004501343 segundos.
# Tempo do primeiro array de 10k: 18.51624035835266 segundos.
# Tempo do primeiro array de 10k: 27.327528476715088 segundos.

# %%
mean_arr_10k_bs = (time_arr1_10k_bs + time_arr2_10k_bs + time_arr3_10k_bs)/3
list_arr_10k_bs = np.array([time_arr1_10k_bs, time_arr2_10k_bs, time_arr3_10k_bs, time_wc_10k_bs, mean_arr_10k_bs])
print(f"Tempo médio de ordenação dos arrays aleatórios de 10k: {mean_arr_10k_bs} segundos.")
# Out:
# Tempo médio de ordenação dos arrays aleatórios de 10k: 18.548984209696453 segundos.

# %%
time_arr1_20k_bs =  tempo_ordenaçao_bs(arr1_20k)
print(f"Tempo do primeiro array de 20k: {time_arr1_20k_bs} segundos.")
time_arr2_20k_bs = tempo_ordenaçao_bs(arr2_20k)
print(f"Tempo do primeiro array de 20k: {time_arr2_20k_bs} segundos.")
time_arr3_20k_bs = tempo_ordenaçao_bs(arr3_20k)
print(f"Tempo do primeiro array de 20k: {time_arr3_20k_bs} segundos.")
time_wc_20k_bs = tempo_ordenaçao_bs(arr_wc_20k)
print(f"Tempo do primeiro array de 20k: {time_wc_20k_bs} segundos.")
# Out:
# Tempo do primeiro array de 20k: 72.87803411483765 segundos.
# Tempo do primeiro array de 20k: 73.86349892616272 segundos.
# Tempo do primeiro array de 20k: 73.87858748435974 segundos.
# Tempo do primeiro array de 20k: 109.36450576782227 segundos.

# %%
mean_arr_20k_bs = (time_arr1_20k_bs + time_arr2_20k_bs + time_arr3_20k_bs)/3
list_arr_20k_bs = np.array([time_arr1_20k_bs, time_arr2_20k_bs, time_arr3_20k_bs, time_wc_20k_bs, mean_arr_20k_bs])
print(f"Tempo médio de ordenação dos arrays aleatórios de 20k: {mean_arr_20k_bs} segundos.")
# Out:
# Tempo médio de ordenação dos arrays aleatórios de 20k: 73.54004017512004 segundos.

# %%
time_arr1_30k_bs =  tempo_ordenaçao_bs(arr1_30k)
print(f"Tempo do primeiro array de 30k: {time_arr1_30k_bs} segundos.")
time_arr2_30k_bs = tempo_ordenaçao_bs(arr2_30k)
print(f"Tempo do primeiro array de 30k: {time_arr2_30k_bs} segundos.")
time_arr3_30k_bs = tempo_ordenaçao_bs(arr3_30k)
print(f"Tempo do primeiro array de 30k: {time_arr3_30k_bs} segundos.")
time_wc_30k_bs = tempo_ordenaçao_bs(arr_wc_30k)
print(f"Tempo do primeiro array de 30k: {time_wc_30k_bs} segundos.")
# Out:
# Tempo do primeiro array de 30k: 170.97640705108643 segundos.
# Tempo do primeiro array de 30k: 171.7066729068756 segundos.

# %%
mean_arr_30k_bs = (time_arr1_30k_bs + time_arr2_30k_bs + time_arr3_30k_bs)/3
list_arr_30k_bs = np.array([time_arr1_30k_bs, time_arr2_30k_bs, time_arr3_30k_bs, time_wc_30k_bs, mean_arr_30k_bs])
print(f"Tempo médio de ordenação dos arrays aleatórios de 30k: {mean_arr_30k_bs} segundos.")
# Out:
# Tempo médio de ordenação dos arrays aleatórios de 30k: 178.04465540250143 segundos.

# %%
time_arr1_40k_bs =  tempo_ordenaçao_bs(arr1_40k)
print(f"Tempo do primeiro array de 40k: {time_arr1_40k_bs} segundos.")
time_arr2_40k_bs = tempo_ordenaçao_bs(arr2_40k)
print(f"Tempo do primeiro array de 40k: {time_arr2_40k_bs} segundos.")
time_arr3_40k_bs = tempo_ordenaçao_bs(arr3_40k)
print(f"Tempo do primeiro array de 40k: {time_arr3_40k_bs} segundos.")
time_wc_40k_bs = tempo_ordenaçao_bs(arr_wc_40k)
print(f"Tempo do primeiro array de 40k: {time_wc_40k_bs} segundos.")
# Out:
# Tempo do primeiro array de 40k: 320.6755437850952 segundos.
# Tempo do primeiro array de 40k: 317.463707447052 segundos.
# Tempo do primeiro array de 40k: 317.41262125968933 segundos.
# Tempo do primeiro array de 40k: 472.335067987442 segundos.

# %%
mean_arr_40k_bs = (time_arr1_40k_bs + time_arr2_40k_bs + time_arr3_40k_bs)/3
list_arr_40k_bs = np.array([time_arr1_40k_bs, time_arr2_40k_bs, time_arr3_40k_bs, time_wc_40k_bs, mean_arr_40k_bs])
print(f"Tempo médio de ordenação dos arrays aleatórios de 40k: {mean_arr_40k_bs} segundos.")
# Out:
# Tempo médio de ordenação dos arrays aleatórios de 40k: 318.5172908306122 segundos.

# %%
time_arr1_50k_bs =  tempo_ordenaçao_bs(arr1_50k)
print(f"Tempo do primeiro array de 50k: {time_arr1_50k_bs} segundos.")
time_arr2_50k_bs = tempo_ordenaçao_bs(arr2_50k)
print(f"Tempo do primeiro array de 50k: {time_arr2_50k_bs} segundos.")
time_arr3_50k_bs = tempo_ordenaçao_bs(arr3_50k)
print(f"Tempo do primeiro array de 50k: {time_arr3_50k_bs} segundos.")
time_wc_50k_bs = tempo_ordenaçao_bs(arr_wc_50k)
print(f"Tempo do primeiro array de 50k: {time_wc_50k_bs} segundos.")
# Out:
# Tempo do primeiro array de 50k: 489.6256580352783 segundos.
# Tempo do primeiro array de 50k: 486.37282371520996 segundos.
# Tempo do primeiro array de 50k: 496.48219561576843 segundos.
# Tempo do primeiro array de 50k: 716.8304123878479 segundos.

# %%
mean_arr_50k_bs = (time_arr1_50k_bs + time_arr2_50k_bs + time_arr3_50k_bs)/3
list_arr_50k_bs = np.array([time_arr1_50k_bs, time_arr2_50k_bs, time_arr3_50k_bs, time_wc_50k_bs, mean_arr_50k_bs])
print(f"Tempo médio de ordenação dos arrays aleatórios de 50k: {mean_arr_50k_bs} segundos.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 list_arr_50k_bs = np.array([time_arr1_50k_bs, time_arr2_50k_bs, time_arr3_50k_bs, time_wc_50k_bs])
#       2 mean_arr_50k_bs = list_arr_50k_bs.mean()
#       3 np.hstack(list_arr_50k_bs, mean_arr_50k_bs)
#
# NameError: name 'time_arr1_50k_bs' is not defined

# %% [markdown]
# ### Estrutura de Índices para `list_arr_(n)k`
#
# 1. `list_arr_(n)k`, onde `(n)k` representa o tamanho do array (ex: 10k, 50k, 100k):
#
# * **Índices `[0]` a `[2]`: Tempos de Execução (Arrays Aleatórios)**
#     * **`[0]`:** Tempo da 1ª execução aleatória.
#     * **`[1]`:** Tempo da 2ª execução aleatória.
#     * **`[2]`:** Tempo da 3ª execução aleatória.
#
# * **Índice `[3]`: Tempo de Execução (Pior Caso)**
#     * Representa o tempo de execução para o array ordenado no pior caso (geralmente decrescente para algoritmos de ordenação).
#
# * **Índice `[4]`: Média dos Tempos Aleatórios**
#     * Valor médio calculado a partir dos tempos nos índices `[0]`, `[1]`, e `[2]`.

# %% [markdown]
# ## 2. Fazendo as listas de tempos e médias do método

# %%
list_bs = np.array([list_arr_1k_bs, list_arr_5k_bs, list_arr_10k_bs, list_arr_20k_bs,
                    list_arr_30k_bs, list_arr_40k_bs, list_arr_50k_bs])

mean_arr_bs = np.array([mean_arr_1k_bs, mean_arr_5k_bs, mean_arr_10k_bs, mean_arr_20k_bs,
                         mean_arr_30k_bs, mean_arr_40k_bs, mean_arr_50k_bs])

# %% [markdown]
# ## 3. Salvando os Dados

# %%
# Salvando os tempos de ordenação
np.save("list_bs", list_bs)
np.sabe("mean_arr_bs", mean_arr_bs)

# %% [markdown]
# ## `Selection Sort`

# %% [markdown]
# ## 1. Calculando os tempos de ordenação

# %%
# Pegando o tempo de ordenação dos 4 arrays
time_arr1_1k_ss =  tempo_ordenaçao_ss(arr1_1k)
print(f"Tempo do primeiro array de 1k: {time_arr1_1k_ss} segundos")
time_arr2_1k_ss = tempo_ordenaçao_ss(arr2_1k)
print(f"Tempo do primeiro array de 1k: {time_arr2_1k_ss} segundos")
time_arr3_1k_ss = tempo_ordenaçao_ss(arr3_1k)
print(f"Tempo do primeiro array de 1k: {time_arr3_1k_ss} segundos")
time_wc_1k_ss = tempo_ordenaçao_ss(arr_wc_1k)
print(f"Tempo do primeiro array de 1k: {time_wc_1k_ss} segundos")

# %%
# Fazendo uma média dos 3 casos dos arrays aleatórios
mean_arr_1k_ss = (time_arr1_1k_ss + time_arr2_1k_ss + time_arr3_1k_ss)/3
list_arr_1k_ss = np.array([time_arr1_1k_ss, time_arr2_1k_ss, time_arr3_1k_ss, time_wc_1k_ss, mean_arr_1k_ss])
print(f"Tempo médio de ordenação dos arrays de 1k: {mean_arr_1k_ss} segundos.")

# %%
time_arr1_5k_ss =  tempo_ordenaçao_bs(arr1_5k.copy())
print(f"Tempo do primeiro array de 5k: {time_arr1_5k_ss} segundos.")
time_arr2_5k_ss = tempo_ordenaçao_bs(arr2_5k.copy())
print(f"Tempo do primeiro array de 5k: {time_arr2_5k_ss} segundos.")
time_arr3_5k_ss = tempo_ordenaçao_bs(arr3_5k.copy())
print(f"Tempo do primeiro array de 5k: {time_arr3_5k_ss} segundos.")
time_wc_5k_ss = tempo_ordenaçao_bs(arr_wc_5k.copy())
print(f"Tempo do primeiro array de 5k: {time_wc_5k_ss} segundos.")

# %%
mean_arr_5k_ss = (time_arr1_5k_ss + time_arr2_5k_ss + time_arr3_5k_ss)/3
list_arr_5k_ss = np.array([time_arr1_5k_ss, time_arr2_5k_ss, time_arr3_5k_ss, time_wc_5k_ss, mean_arr_5k_ss])
print(f"Tempo médio de ordenação dos arrays de 5k {mean_arr_5k_ss} segundos.")

# %%
time_arr1_10k_ss = tempo_ordenaçao_ss(arr1_10k.copy())
print(f"Tempo do primeiro array de 10k: {time_arr1_10k_ss} segundos.")
time_arr2_10k_ss = tempo_ordenaçao_ss(arr2_10k.copy())
print(f"Tempo do primeiro array de 10k: {time_arr2_10k_ss} segundos.")
time_arr3_10k_ss = tempo_ordenaçao_ss(arr3_10k.copy())
print(f"Tempo do primeiro array de 10k: {time_arr3_10k_ss} segundos.")
time_wc_10k_ss = tempo_ordenaçao_ss(arr_wc_10k.copy())
print(f"Tempo do primeiro array de 10k: {time_wc_10k_ss} segundos.")

# %%
mean_arr_10k_ss = (time_arr1_10k_ss + time_arr2_10k_ss + time_arr3_10k_ss)/3
list_arr_10k_ss = np.array([time_arr1_10k_ss, time_arr2_10k_ss, time_arr3_10k_ss, time_wc_10k_ss, mean_arr_10k_ss])
print(f"Tempo médio de ordenação dos arrays aleatórios de 10k: {mean_arr_10k_ss} segundos.")

# %%
time_arr1_20k_ss = tempo_ordenaçao_ss(arr1_20k)
print(f"Tempo do primeiro array de 20k: {time_arr1_20k_ss} segundos.")
time_arr2_20k_ss = tempo_ordenaçao_ss(arr2_20k)
print(f"Tempo do primeiro array de 20k: {time_arr2_20k_ss} segundos.")
time_arr3_20k_ss = tempo_ordenaçao_ss(arr3_20k)
print(f"Tempo do primeiro array de 20k: {time_arr3_20k_ss} segundos.")
time_wc_20k_ss = tempo_ordenaçao_ss(arr_wc_20k)
print(f"Tempo do primeiro array de 20k: {time_wc_20k_ss} segundos.")

# %%
mean_arr_20k_ss = (time_arr1_20k_ss + time_arr2_20k_ss + time_arr3_20k_ss)/3
list_arr_20k_ss = np.array([time_arr1_20k_ss, time_arr2_20k_ss, time_arr3_20k_ss, time_wc_20k_ss, mean_arr_20k_ss])
print(f"Tempo médio de ordenação dos arrays aleatórios de 20k: {mean_arr_20k_ss} segundos.")

# %%
time_arr1_30k_ss = tempo_ordenaçao_ss(arr1_30k)
print(f"Tempo do primeiro array de 30k: {time_arr1_30k_ss} segundos.")
time_arr2_30k_ss = tempo_ordenaçao_ss(arr2_30k)
print(f"Tempo do primeiro array de 30k: {time_arr2_30k_ss} segundos.")
time_arr3_30k_ss = tempo_ordenaçao_ss(arr3_30k)
print(f"Tempo do primeiro array de 30k: {time_arr3_30k_ss} segundos.")
time_wc_30k_ss = tempo_ordenaçao_ss(arr_wc_30k)
print(f"Tempo do primeiro array de 30k: {time_wc_30k_ss} segundos.")

# %%
mean_arr_30k_ss = (time_arr1_30k_ss + time_arr2_30k_ss + time_arr3_30k_ss)/3
list_arr_30k_ss = np.array([time_arr1_30k_ss, time_arr2_30k_ss, time_arr3_30k_ss, time_wc_30k_ss, mean_arr_30k_ss])
print(f"Tempo médio de ordenação dos arrays aleatórios de 30k: {mean_arr_30k_ss} segundos.")

# %%
time_arr1_40k_ss = tempo_ordenaçao_ss(arr1_40k)
print(f"Tempo do primeiro array de 40k: {time_arr1_40k_ss} segundos.")
time_arr2_40k_ss = tempo_ordenaçao_ss(arr2_40k)
print(f"Tempo do primeiro array de 40k: {time_arr2_40k_ss} segundos.")
time_arr3_40k_ss = tempo_ordenaçao_ss(arr3_40k)
print(f"Tempo do primeiro array de 40k: {time_arr3_40k_ss} segundos.")
time_wc_40k_ss = tempo_ordenaçao_ss(arr_wc_40k)
print(f"Tempo do primeiro array de 40k: {time_wc_40k_ss} segundos.")

# %%
mean_arr_40k_ss = (time_arr1_40k_ss + time_arr2_40k_ss + time_arr3_40k_ss)/3
list_arr_40k_ss = np.array([time_arr1_40k_ss, time_arr2_40k_ss, time_arr3_40k_ss, time_wc_40k_ss, mean_arr_40k_ss])
print(f"Tempo médio de ordenação dos arrays aleatórios de 40k: {mean_arr_40k_ss} segundos.")

# %%
time_arr1_50k_ss = tempo_ordenaçao_ss(arr1_50k)
print(f"Tempo do primeiro array de 50k: {time_arr1_50k_ss} segundos.")
time_arr2_50k_ss = tempo_ordenaçao_ss(arr2_50k)
print(f"Tempo do primeiro array de 50k: {time_arr2_50k_ss} segundos.")
time_arr3_50k_ss = tempo_ordenaçao_ss(arr3_50k)
print(f"Tempo do primeiro array de 50k: {time_arr3_50k_ss} segundos.")
time_wc_50k_ss = tempo_ordenaçao_ss(arr_wc_50k)
print(f"Tempo do primeiro array de 50k: {time_wc_50k_ss} segundos.")

# %%
mean_arr_50k_ss = (time_arr1_50k_ss + time_arr2_50k_ss + time_arr3_50k_ss)/3
list_arr_50k_ss = np.array([time_arr1_50k_ss, time_arr2_50k_ss, time_arr3_50k_ss, time_wc_50k_ss, mean_arr_50k_ss])
print(f"Tempo médio de ordenação dos arrays aleatórios de 50k: {mean_arr_50k_ss} segundos.")

# %% [markdown]
# ## 2. Fazendo as listas de tempos e médias do método

# %%
list_ss = np.array([list_arr_1k_ss, list_arr_5k_ss, list_arr_10k_ss, list_arr_20k_ss,
                        list_arr_30k_ss, list_arr_40k_ss, list_arr_50k_ss])

mean_arr_ss = np.array([mean_arr_1k_ss, mean_arr_5k_ss, mean_arr_10k_ss, mean_arr_20k_ss,
                        mean_arr_30k_ss, mean_arr_40k_ss, mean_arr_50k_ss])

# %% [markdown]
# ## 3. Salvando os Dados

# %%
np.save("list_ss", list_ss)
np.save("mean_arr_ss", mean_arr_ss)

# %% [markdown]
# ## `Insertion Sort`

# %% [markdown]
# ## 1. Calculando os tempos de ordenação

# %%
# Pegando o tempo de ordenação dos 4 arrays (1k)
time_arr1_1k_ins = tempo_ordenaçao_ins(arr1_1k)
print(f"Tempo do primeiro array de 1k: {time_arr1_1k_ins} segundos")
time_arr2_1k_ins = tempo_ordenaçao_ins(arr2_1k)
print(f"Tempo do primeiro array de 1k: {time_arr2_1k_ins} segundos")
time_arr3_1k_ins = tempo_ordenaçao_ins(arr3_1k)
print(f"Tempo do primeiro array de 1k: {time_arr3_1k_ins} segundos")
time_wc_1k_ins = tempo_ordenaçao_ins(arr_wc_1k)
print(f"Tempo do primeiro array de 1k: {time_wc_1k_ins} segundos")

# %%
# Fazendo uma média dos 3 casos dos arrays aleatórios (1k)
mean_arr_1k_ins = (time_arr1_1k_ins + time_arr2_1k_ins + time_arr3_1k_ins)/3
list_arr_1k_ins = np.array([time_arr1_1k_ins, time_arr2_1k_ins, time_arr3_1k_ins, time_wc_1k_ins, mean_arr_1k_ins])
print(f"Tempo médio de ordenação dos arrays de 1k: {mean_arr_1k_ins} segundos.")

# %%
# Pegando o tempo de ordenação dos 4 arrays (5k)
time_arr1_5k_ins = tempo_ordenaçao_ins(arr1_5k.copy())
print(f"Tempo do primeiro array de 5k: {time_arr1_5k_ins} segundos.")
time_arr2_5k_ins = tempo_ordenaçao_ins(arr2_5k.copy())
print(f"Tempo do primeiro array de 5k: {time_arr2_5k_ins} segundos.")
time_arr3_5k_ins = tempo_ordenaçao_ins(arr3_5k.copy())
print(f"Tempo do primeiro array de 5k: {time_arr3_5k_ins} segundos.")
time_wc_5k_ins = tempo_ordenaçao_ins(arr_wc_5k.copy())
print(f"Tempo do primeiro array de 5k: {time_wc_5k_ins} segundos.")

# %%
# Continuacão do código original (5k e superior)
mean_arr_5k_ins = (time_arr1_5k_ins + time_arr2_5k_ins + time_arr3_5k_ins)/3
list_arr_5k_ins = np.array([time_arr1_5k_ins, time_arr2_5k_ins, time_arr3_5k_ins, time_wc_5k_ins, mean_arr_5k_ins])
print(f"Tempo médio de ordenação dos arrays de 5k {mean_arr_5k_ins} segundos.")

# %%
time_arr1_10k_ins = tempo_ordenaçao_ins(arr1_10k.copy())
print(f"Tempo do primeiro array de 10k: {time_arr1_10k_ins} segundos.")
time_arr2_10k_ins = tempo_ordenaçao_ins(arr2_10k.copy())
print(f"Tempo do primeiro array de 10k: {time_arr2_10k_ins} segundos.")
time_arr3_10k_ins = tempo_ordenaçao_ins(arr3_10k.copy())
print(f"Tempo do primeiro array de 10k: {time_arr3_10k_ins} segundos.")
time_wc_10k_ins = tempo_ordenaçao_ins(arr_wc_10k.copy())
print(f"Tempo do primeiro array de 10k: {time_wc_10k_ins} segundos.")

# %%
mean_arr_10k_ins = (time_arr1_10k_ins + time_arr2_10k_ins + time_arr3_10k_ins)/3
list_arr_10k_ins = np.array([time_arr1_10k_ins, time_arr2_10k_ins, time_arr3_10k_ins, time_wc_10k_ins, mean_arr_10k_ins])
print(f"Tempo médio de ordenação dos arrays aleatórios de 10k: {mean_arr_10k_ins} segundos.")

# %%
time_arr1_20k_ins = tempo_ordenaçao_ins(arr1_20k)
print(f"Tempo do primeiro array de 20k: {time_arr1_20k_ins} segundos.")
time_arr2_20k_ins = tempo_ordenaçao_ins(arr2_20k)
print(f"Tempo do primeiro array de 20k: {time_arr2_20k_ins} segundos.")
time_arr3_20k_ins = tempo_ordenaçao_ins(arr3_20k)
print(f"Tempo do primeiro array de 20k: {time_arr3_20k_ins} segundos.")
time_wc_20k_ins = tempo_ordenaçao_ins(arr_wc_20k)
print(f"Tempo do primeiro array de 20k: {time_wc_20k_ins} segundos.")

# %%
mean_arr_20k_ins = (time_arr1_20k_ins + time_arr2_20k_ins + time_arr3_20k_ins)/3
list_arr_20k_ins = np.array([time_arr1_20k_ins, time_arr2_20k_ins, time_arr3_20k_ins, time_wc_20k_ins, mean_arr_20k_ins])
print(f"Tempo médio de ordenação dos arrays aleatórios de 20k: {mean_arr_20k_ins} segundos.")

# %%
time_arr1_30k_ins = tempo_ordenaçao_ins(arr1_30k)
print(f"Tempo do primeiro array de 30k: {time_arr1_30k_ins} segundos.")
time_arr2_30k_ins = tempo_ordenaçao_ins(arr2_30k)
print(f"Tempo do primeiro array de 30k: {time_arr2_30k_ins} segundos.")
time_arr3_30k_ins = tempo_ordenaçao_ins(arr3_30k)
print(f"Tempo do primeiro array de 30k: {time_arr3_30k_ins} segundos.")
time_wc_30k_ins = tempo_ordenaçao_ins(arr_wc_30k)
print(f"Tempo do primeiro array de 30k: {time_wc_30k_ins} segundos.")

# %%
mean_arr_30k_ins = (time_arr1_30k_ins + time_arr2_30k_ins + time_arr3_30k_ins)/3
list_arr_30k_ins = np.array([time_arr1_30k_ins, time_arr2_30k_ins, time_arr3_30k_ins, time_wc_30k_ins, mean_arr_30k_ins])
print(f"Tempo médio de ordenação dos arrays aleatórios de 30k: {mean_arr_30k_ins} segundos.")

# %%
time_arr1_40k_ins = tempo_ordenaçao_ins(arr1_40k)
print(f"Tempo do primeiro array de 40k: {time_arr1_40k_ins} segundos.")
time_arr2_40k_ins = tempo_ordenaçao_ins(arr2_40k)
print(f"Tempo do primeiro array de 40k: {time_arr2_40k_ins} segundos.")
time_arr3_40k_ins = tempo_ordenaçao_ins(arr3_40k)
print(f"Tempo do primeiro array de 40k: {time_arr3_40k_ins} segundos.")
time_wc_40k_ins = tempo_ordenaçao_ins(arr_wc_40k)
print(f"Tempo do primeiro array de 40k: {time_wc_40k_ins} segundos.")

# %%
mean_arr_40k_ins = (time_arr1_40k_ins + time_arr2_40k_ins + time_arr3_40k_ins)/3
list_arr_40k_ins = np.array([time_arr1_40k_ins, time_arr2_40k_ins, time_arr3_40k_ins, time_wc_40k_ins, mean_arr_40k_ins])
print(f"Tempo médio de ordenação dos arrays aleatórios de 40k: {mean_arr_40k_ins} segundos.")

# %%
time_arr1_50k_ins = tempo_ordenaçao_ins(arr1_50k)
print(f"Tempo do primeiro array de 50k: {time_arr1_50k_ins} segundos.")
time_arr2_50k_ins = tempo_ordenaçao_ins(arr2_50k)
print(f"Tempo do primeiro array de 50k: {time_arr2_50k_ins} segundos.")
time_arr3_50k_ins = tempo_ordenaçao_ins(arr3_50k)
print(f"Tempo do primeiro array de 50k: {time_arr3_50k_ins} segundos.")
time_wc_50k_ins = tempo_ordenaçao_ins(arr_wc_50k)
print(f"Tempo do primeiro array de 50k: {time_wc_50k_ins} segundos.")

# %%
mean_arr_50k_ins = (time_arr1_50k_ins + time_arr2_50k_ins + time_arr3_50k_ins)/3
list_arr_50k_ins = np.array([time_arr1_50k_ins, time_arr2_50k_ins, time_arr3_50k_ins, time_wc_50k_ins, mean_arr_50k_ins])
print(f"Tempo médio de ordenação dos arrays aleatórios de 50k: {mean_arr_50k_ins} segundos.")

# %% [markdown]
# ## 2. Fazendo as listas de tempos e médias do método

# %%
# Definição das variáveis _ins
list_ins = np.array([list_arr_1k_ins, list_arr_5k_ins, list_arr_10k_ins, list_arr_20k_ins,
                    list_arr_30k_ins, list_arr_40k_ins, list_arr_50k_ins])

mean_arr_ins = np.array([mean_arr_1k_ins, mean_arr_5k_ins, mean_arr_10k_ins, mean_arr_20k_ins,
                    mean_arr_30k_ins, mean_arr_40k_ins, mean_arr_50k_ins])

# %% [markdown]
# ## 3. Salvando os Dados

# %%
# Comandos para salvar os arrays _ins
np.save("list_ins", list_ins)
np.save("mean_arr_ins", mean_arr_ins)

# %% [markdown]
# ## `Shell Sort`

# %% [markdown]
# ## 1. Calculando os tempos de ordenação

# %%
# Pegando o tempo de ordenação dos 4 arrays (1k)
time_arr1_1k_sh = tempo_ordenaçao_sh(arr1_1k)
print(f"Tempo do primeiro array de 1k: {time_arr1_1k_sh} segundos")
time_arr2_1k_sh = tempo_ordenaçao_sh(arr2_1k)
print(f"Tempo do primeiro array de 1k: {time_arr2_1k_sh} segundos")
time_arr3_1k_sh = tempo_ordenaçao_sh(arr3_1k)
print(f"Tempo do primeiro array de 1k: {time_arr3_1k_sh} segundos")
time_wc_1k_sh = tempo_ordenaçao_sh(arr_wc_1k)
print(f"Tempo do primeiro array de 1k: {time_wc_1k_sh} segundos")

# %%
# Fazendo uma média dos 3 casos dos arrays aleatórios (1k)
mean_arr_1k_sh = (time_arr1_1k_sh + time_arr2_1k_sh + time_arr3_1k_sh)/3
list_arr_1k_sh = np.array([time_arr1_1k_sh, time_arr2_1k_sh, time_arr3_1k_sh, time_wc_1k_sh, mean_arr_1k_sh])
print(f"Tempo médio de ordenação dos arrays de 1k: {mean_arr_1k_sh} segundos.")

# %%
# Pegando o tempo de ordenação dos 4 arrays (5k)
time_arr1_5k_sh = tempo_ordenaçao_sh(arr1_5k.copy())
print(f"Tempo do primeiro array de 5k: {time_arr1_5k_sh} segundos.")
time_arr2_5k_sh = tempo_ordenaçao_sh(arr2_5k.copy())
print(f"Tempo do primeiro array de 5k: {time_arr2_5k_sh} segundos.")
time_arr3_5k_sh = tempo_ordenaçao_sh(arr3_5k.copy())
print(f"Tempo do primeiro array de 5k: {time_arr3_5k_sh} segundos.")
time_wc_5k_sh = tempo_ordenaçao_sh(arr_wc_5k.copy())
print(f"Tempo do primeiro array de 5k: {time_wc_5k_sh} segundos.")

# %%
# Continuacão do código original (5k e superior)
mean_arr_5k_sh = (time_arr1_5k_sh + time_arr2_5k_sh + time_arr3_5k_sh)/3
list_arr_5k_sh = np.array([time_arr1_5k_sh, time_arr2_5k_sh, time_arr3_5k_sh, time_wc_5k_sh, mean_arr_5k_sh])
print(f"Tempo médio de ordenação dos arrays de 5k {mean_arr_5k_sh} segundos.")

# %%
time_arr1_10k_sh = tempo_ordenaçao_sh(arr1_10k.copy())
print(f"Tempo do primeiro array de 10k: {time_arr1_10k_sh} segundos.")
time_arr2_10k_sh = tempo_ordenaçao_sh(arr2_10k.copy())
print(f"Tempo do primeiro array de 10k: {time_arr2_10k_sh} segundos.")
time_arr3_10k_sh = tempo_ordenaçao_sh(arr3_10k.copy())
print(f"Tempo do primeiro array de 10k: {time_arr3_10k_sh} segundos.")
time_wc_10k_sh = tempo_ordenaçao_sh(arr_wc_10k.copy())
print(f"Tempo do primeiro array de 10k: {time_wc_10k_sh} segundos.")

# %%
mean_arr_10k_sh = (time_arr1_10k_sh + time_arr2_10k_sh + time_arr3_10k_sh)/3
list_arr_10k_sh = np.array([time_arr1_10k_sh, time_arr2_10k_sh, time_arr3_10k_sh, time_wc_10k_sh, mean_arr_10k_sh])
print(f"Tempo médio de ordenação dos arrays aleatórios de 10k: {mean_arr_10k_sh} segundos.")

# %%
time_arr1_20k_sh = tempo_ordenaçao_sh(arr1_20k)
print(f"Tempo do primeiro array de 20k: {time_arr1_20k_sh} segundos.")
time_arr2_20k_sh = tempo_ordenaçao_sh(arr2_20k)
print(f"Tempo do primeiro array de 20k: {time_arr2_20k_sh} segundos.")
time_arr3_20k_sh = tempo_ordenaçao_sh(arr3_20k)
print(f"Tempo do primeiro array de 20k: {time_arr3_20k_sh} segundos.")
time_wc_20k_sh = tempo_ordenaçao_sh(arr_wc_20k)
print(f"Tempo do primeiro array de 20k: {time_wc_20k_sh} segundos.")

# %%
mean_arr_20k_sh = (time_arr1_20k_sh + time_arr2_20k_sh + time_arr3_20k_sh)/3
list_arr_20k_sh = np.array([time_arr1_20k_sh, time_arr2_20k_sh, time_arr3_20k_sh, time_wc_20k_sh, mean_arr_20k_sh])
print(f"Tempo médio de ordenação dos arrays aleatórios de 20k: {mean_arr_20k_sh} segundos.")

# %%
time_arr1_30k_sh = tempo_ordenaçao_sh(arr1_30k)
print(f"Tempo do primeiro array de 30k: {time_arr1_30k_sh} segundos.")
time_arr2_30k_sh = tempo_ordenaçao_sh(arr2_30k)
print(f"Tempo do primeiro array de 30k: {time_arr2_30k_sh} segundos.")
time_arr3_30k_sh = tempo_ordenaçao_sh(arr3_30k)
print(f"Tempo do primeiro array de 30k: {time_arr3_30k_sh} segundos.")
time_wc_30k_sh = tempo_ordenaçao_sh(arr_wc_30k)
print(f"Tempo do primeiro array de 30k: {time_wc_30k_sh} segundos.")

# %%
mean_arr_30k_sh = (time_arr1_30k_sh + time_arr2_30k_sh + time_arr3_30k_sh)/3
list_arr_30k_sh = np.array([time_arr1_30k_sh, time_arr2_30k_sh, time_arr3_30k_sh, time_wc_30k_sh, mean_arr_30k_sh])
print(f"Tempo médio de ordenação dos arrays aleatórios de 30k: {mean_arr_30k_sh} segundos.")

# %%
time_arr1_40k_sh = tempo_ordenaçao_sh(arr1_40k)
print(f"Tempo do primeiro array de 40k: {time_arr1_40k_sh} segundos.")
time_arr2_40k_sh = tempo_ordenaçao_sh(arr2_40k)
print(f"Tempo do primeiro array de 40k: {time_arr2_40k_sh} segundos.")
time_arr3_40k_sh = tempo_ordenaçao_sh(arr3_40k)
print(f"Tempo do primeiro array de 40k: {time_arr3_40k_sh} segundos.")
time_wc_40k_sh = tempo_ordenaçao_sh(arr_wc_40k)
print(f"Tempo do primeiro array de 40k: {time_wc_40k_sh} segundos.")

# %%
mean_arr_40k_sh = (time_arr1_40k_sh + time_arr2_40k_sh + time_arr3_40k_sh)/3
list_arr_40k_sh = np.array([time_arr1_40k_sh, time_arr2_40k_sh, time_arr3_40k_sh, time_wc_40k_sh, mean_arr_40k_sh])
print(f"Tempo médio de ordenação dos arrays aleatórios de 40k: {mean_arr_40k_sh} segundos.")

# %%
time_arr1_50k_sh = tempo_ordenaçao_sh(arr1_50k)
print(f"Tempo do primeiro array de 50k: {time_arr1_50k_sh} segundos.")
time_arr2_50k_sh = tempo_ordenaçao_sh(arr2_50k)
print(f"Tempo do primeiro array de 50k: {time_arr2_50k_sh} segundos.")
time_arr3_50k_sh = tempo_ordenaçao_sh(arr3_50k)
print(f"Tempo do primeiro array de 50k: {time_arr3_50k_sh} segundos.")
time_wc_50k_sh = tempo_ordenaçao_sh(arr_wc_50k)
print(f"Tempo do primeiro array de 50k: {time_wc_50k_sh} segundos.")

# %%
mean_arr_50k_sh = (time_arr1_50k_sh + time_arr2_50k_sh + time_arr3_50k_sh)/3
list_arr_50k_sh = np.array([time_arr1_50k_sh, time_arr2_50k_sh, time_arr3_50k_sh, time_wc_50k_sh, mean_arr_50k_sh])
print(f"Tempo médio de ordenação dos arrays aleatórios de 50k: {mean_arr_50k_sh} segundos.")

# %% [markdown]
# ## 2. Fazendo as listas de tempos e médias do método

# %%
list_sh = np.array([list_arr_1k_sh, list_arr_5k_sh, list_arr_10k_sh, list_arr_20k_sh,
                    list_arr_30k_sh, list_arr_40k_sh, list_arr_50k_sh])

mean_arr_sh = np.array([mean_arr_1k_sh, mean_arr_5k_sh, mean_arr_10k_sh, mean_arr_20k_sh,
                        mean_arr_30k_sh, mean_arr_40k_sh, mean_arr_50k_sh])

# %% [markdown]
# ## 3. Salvando os Dados

# %% [markdown]
# np.save("list_sh", list_sh)
# np.save("mean_arr_sh", mean_arr_sh)

# %% [markdown]
# ## `Quick Sort`

# %% [markdown]
# ## 1. Calculando os tempos de ordenação

# %%
# Pegando o tempo de ordenação dos 4 arrays (1k)
time_arr1_1k_qs = tempo_ordenaçao_qs(arr1_1k)
print(f"Tempo do primeiro array de 1k: {time_arr1_1k_qs} segundos")
time_arr2_1k_qs = tempo_ordenaçao_qs(arr2_1k)
print(f"Tempo do primeiro array de 1k: {time_arr2_1k_qs} segundos")
time_arr3_1k_qs = tempo_ordenaçao_qs(arr3_1k)
print(f"Tempo do primeiro array de 1k: {time_arr3_1k_qs} segundos")
time_wc_1k_qs = tempo_ordenaçao_qs(arr_wc_1k)
print(f"Tempo do primeiro array de 1k: {time_wc_1k_qs} segundos")

# %%
# Fazendo uma média dos 3 casos dos arrays aleatórios (1k)
mean_arr_1k_qs = (time_arr1_1k_qs + time_arr2_1k_qs + time_arr3_1k_qs)/3
list_arr_1k_qs = np.array([time_arr1_1k_qs, time_arr2_1k_qs, time_arr3_1k_qs, time_wc_1k_qs, mean_arr_1k_qs])
print(f"Tempo médio de ordenação dos arrays de 1k: {mean_arr_1k_qs} segundos.")

# %%
# Pegando o tempo de ordenação dos 4 arrays (5k)
time_arr1_5k_qs = tempo_ordenaçao_qs(arr1_5k.copy())
print(f"Tempo do primeiro array de 5k: {time_arr1_5k_qs} segundos.")
time_arr2_5k_qs = tempo_ordenaçao_qs(arr2_5k.copy())
print(f"Tempo do primeiro array de 5k: {time_arr2_5k_qs} segundos.")
time_arr3_5k_qs = tempo_ordenaçao_qs(arr3_5k.copy())
print(f"Tempo do primeiro array de 5k: {time_arr3_5k_qs} segundos.")
time_wc_5k_qs = tempo_ordenaçao_qs(arr_wc_5k.copy())
print(f"Tempo do primeiro array de 5k: {time_wc_5k_qs} segundos.")

# %%
# Continuacão do código original (5k e superior)
mean_arr_5k_qs = (time_arr1_5k_qs + time_arr2_5k_qs + time_arr3_5k_qs)/3
list_arr_5k_qs = np.array([time_arr1_5k_qs, time_arr2_5k_qs, time_arr3_5k_qs, time_wc_5k_qs, mean_arr_5k_qs])
print(f"Tempo médio de ordenação dos arrays de 5k {mean_arr_5k_qs} segundos.")

# %%
time_arr1_10k_qs = tempo_ordenaçao_qs(arr1_10k.copy())
print(f"Tempo do primeiro array de 10k: {time_arr1_10k_qs} segundos.")
time_arr2_10k_qs = tempo_ordenaçao_qs(arr2_10k.copy())
print(f"Tempo do primeiro array de 10k: {time_arr2_10k_qs} segundos.")
time_arr3_10k_qs = tempo_ordenaçao_qs(arr3_10k.copy())
print(f"Tempo do primeiro array de 10k: {time_arr3_10k_qs} segundos.")
time_wc_10k_qs = tempo_ordenaçao_qs(arr_wc_10k.copy())
print(f"Tempo do primeiro array de 10k: {time_wc_10k_qs} segundos.")

# %%
mean_arr_10k_qs = (time_arr1_10k_qs + time_arr2_10k_qs + time_arr3_10k_qs)/3
list_arr_10k_qs = np.array([time_arr1_10k_qs, time_arr2_10k_qs, time_arr3_10k_qs, time_wc_10k_qs, mean_arr_10k_qs])
print(f"Tempo médio de ordenação dos arrays aleatórios de 10k: {mean_arr_10k_qs} segundos.")

# %%
time_arr1_20k_qs = tempo_ordenaçao_qs(arr1_20k)
print(f"Tempo do primeiro array de 20k: {time_arr1_20k_qs} segundos.")
time_arr2_20k_qs = tempo_ordenaçao_qs(arr2_20k)
print(f"Tempo do primeiro array de 20k: {time_arr2_20k_qs} segundos.")
time_arr3_20k_qs = tempo_ordenaçao_qs(arr3_20k)
print(f"Tempo do primeiro array de 20k: {time_arr3_20k_qs} segundos.")
time_wc_20k_qs = tempo_ordenaçao_qs(arr_wc_20k)
print(f"Tempo do primeiro array de 20k: {time_wc_20k_qs} segundos.")

# %%
mean_arr_20k_qs = (time_arr1_20k_qs + time_arr2_20k_qs + time_arr3_20k_qs)/3
list_arr_20k_qs = np.array([time_arr1_20k_qs, time_arr2_20k_qs, time_arr3_20k_qs, time_wc_20k_qs, mean_arr_20k_qs])
print(f"Tempo médio de ordenação dos arrays aleatórios de 20k: {mean_arr_20k_qs} segundos.")

# %%
time_arr1_30k_qs = tempo_ordenaçao_qs(arr1_30k)
print(f"Tempo do primeiro array de 30k: {time_arr1_30k_qs} segundos.")
time_arr2_30k_qs = tempo_ordenaçao_qs(arr2_30k)
print(f"Tempo do primeiro array de 30k: {time_arr2_30k_qs} segundos.")
time_arr3_30k_qs = tempo_ordenaçao_qs(arr3_30k)
print(f"Tempo do primeiro array de 30k: {time_arr3_30k_qs} segundos.")
time_wc_30k_qs = tempo_ordenaçao_qs(arr_wc_30k)
print(f"Tempo do primeiro array de 30k: {time_wc_30k_qs} segundos.")

# %%
mean_arr_30k_qs = (time_arr1_30k_qs + time_arr2_30k_qs + time_arr3_30k_qs)/3
list_arr_30k_qs = np.array([time_arr1_30k_qs, time_arr2_30k_qs, time_arr3_30k_qs, time_wc_30k_qs, mean_arr_30k_qs])
print(f"Tempo médio de ordenação dos arrays aleatórios de 30k: {mean_arr_30k_qs} segundos.")

# %%
time_arr1_40k_qs = tempo_ordenaçao_qs(arr1_40k)
print(f"Tempo do primeiro array de 40k: {time_arr1_40k_qs} segundos.")
time_arr2_40k_qs = tempo_ordenaçao_qs(arr2_40k)
print(f"Tempo do primeiro array de 40k: {time_arr2_40k_qs} segundos.")
time_arr3_40k_qs = tempo_ordenaçao_qs(arr3_40k)
print(f"Tempo do primeiro array de 40k: {time_arr3_40k_qs} segundos.")
time_wc_40k_qs = tempo_ordenaçao_qs(arr_wc_40k)
print(f"Tempo do primeiro array de 40k: {time_wc_40k_qs} segundos.")

# %%
mean_arr_40k_qs = (time_arr1_40k_qs + time_arr2_40k_qs + time_arr3_40k_qs)/3
list_arr_40k_qs = np.array([time_arr1_40k_qs, time_arr2_40k_qs, time_arr3_40k_qs, time_wc_40k_qs, mean_arr_40k_qs])
print(f"Tempo médio de ordenação dos arrays aleatórios de 40k: {mean_arr_40k_qs} segundos.")

# %%
time_arr1_50k_qs = tempo_ordenaçao_qs(arr1_50k)
print(f"Tempo do primeiro array de 50k: {time_arr1_50k_qs} segundos.")
time_arr2_50k_qs = tempo_ordenaçao_qs(arr2_50k)
print(f"Tempo do primeiro array de 50k: {time_arr2_50k_qs} segundos.")
time_arr3_50k_qs = tempo_ordenaçao_qs(arr3_50k)
print(f"Tempo do primeiro array de 50k: {time_arr3_50k_qs} segundos.")
time_wc_50k_qs = tempo_ordenaçao_qs(arr_wc_50k)
print(f"Tempo do primeiro array de 50k: {time_wc_50k_qs} segundos.")

# %%
mean_arr_50k_qs = (time_arr1_50k_qs + time_arr2_50k_qs + time_arr3_50k_qs)/3
list_arr_50k_qs = np.array([time_arr1_50k_qs, time_arr2_50k_qs, time_arr3_50k_qs, time_wc_50k_qs, mean_arr_50k_qs])
print(f"Tempo médio de ordenação dos arrays aleatórios de 50k: {mean_arr_50k_qs} segundos.")

# %% [markdown]
# ## 2. Fazendo as listas de tempos e médias do método

# %%
# Definição das variáveis _qs
list_qs = np.array([list_arr_1k_qs, list_arr_5k_qs, list_arr_10k_qs, list_arr_20k_qs,
                     list_arr_30k_qs, list_arr_40k_qs, list_arr_50k_qs])

mean_arr_qs = np.array([mean_arr_1k_qs, mean_arr_5k_qs, mean_arr_10k_qs, mean_arr_20k_qs,
                        mean_arr_30k_qs, mean_arr_40k_qs, mean_arr_50k_qs])

# %% [markdown]
# ## 3. Salvando os Dados

# %%
# Comandos para salvar os arrays _qs
np.save("list_qs", list_qs)
np.save("mean_arr_qs", mean_arr_qs)

# %% [markdown]
# ## `Merge Sort`

# %% [markdown]
# ## 1. Calculando os tempos de ordenação

# %%
# Pegando o tempo de ordenação dos 4 arrays (1k)
time_arr1_1k_ms = tempo_ordenaçao_ms(arr1_1k)
print(f"Tempo do primeiro array de 1k: {time_arr1_1k_ms} segundos")
time_arr2_1k_ms = tempo_ordenaçao_ms(arr2_1k)
print(f"Tempo do primeiro array de 1k: {time_arr2_1k_ms} segundos")
time_arr3_1k_ms = tempo_ordenaçao_ms(arr3_1k)
print(f"Tempo do primeiro array de 1k: {time_arr3_1k_ms} segundos")
time_wc_1k_ms = tempo_ordenaçao_ms(arr_wc_1k)
print(f"Tempo do primeiro array de 1k: {time_wc_1k_ms} segundos")

# %%
# Fazendo uma média dos 3 casos dos arrays aleatórios (1k)
mean_arr_1k_ms = (time_arr1_1k_ms + time_arr2_1k_ms + time_arr3_1k_ms)/3
list_arr_1k_ms = np.array([time_arr1_1k_ms, time_arr2_1k_ms, time_arr3_1k_ms, time_wc_1k_ms, mean_arr_1k_ms])
print(f"Tempo médio de ordenação dos arrays de 1k: {mean_arr_1k_ms} segundos.")

# %%
# Pegando o tempo de ordenação dos 4 arrays (5k)
time_arr1_5k_ms = tempo_ordenaçao_ms(arr1_5k.copy())
print(f"Tempo do primeiro array de 5k: {time_arr1_5k_ms} segundos.")
time_arr2_5k_ms = tempo_ordenaçao_ms(arr2_5k.copy())
print(f"Tempo do primeiro array de 5k: {time_arr2_5k_ms} segundos.")
time_arr3_5k_ms = tempo_ordenaçao_ms(arr3_5k.copy())
print(f"Tempo do primeiro array de 5k: {time_arr3_5k_ms} segundos.")
time_wc_5k_ms = tempo_ordenaçao_ms(arr_wc_5k.copy())
print(f"Tempo do primeiro array de 5k: {time_wc_5k_ms} segundos.")

# %%
# Continuacão do código original (5k e superior)
mean_arr_5k_ms = (time_arr1_5k_ms + time_arr2_5k_ms + time_arr3_5k_ms)/3
list_arr_5k_ms = np.array([time_arr1_5k_ms, time_arr2_5k_ms, time_arr3_5k_ms, time_wc_5k_ms, mean_arr_5k_ms])
print(f"Tempo médio de ordenação dos arrays de 5k {mean_arr_5k_ms} segundos.")

# %%
time_arr1_10k_ms = tempo_ordenaçao_ms(arr1_10k.copy())
print(f"Tempo do primeiro array de 10k: {time_arr1_10k_ms} segundos.")
time_arr2_10k_ms = tempo_ordenaçao_ms(arr2_10k.copy())
print(f"Tempo do primeiro array de 10k: {time_arr2_10k_ms} segundos.")
time_arr3_10k_ms = tempo_ordenaçao_ms(arr3_10k.copy())
print(f"Tempo do primeiro array de 10k: {time_arr3_10k_ms} segundos.")
time_wc_10k_ms = tempo_ordenaçao_ms(arr_wc_10k.copy())
print(f"Tempo do primeiro array de 10k: {time_wc_10k_ms} segundos.")

# %%
mean_arr_10k_ms = (time_arr1_10k_ms + time_arr2_10k_ms + time_arr3_10k_ms)/3
list_arr_10k_ms = np.array([time_arr1_10k_ms, time_arr2_10k_ms, time_arr3_10k_ms, time_wc_10k_ms, mean_arr_10k_ms])
print(f"Tempo médio de ordenação dos arrays aleatórios de 10k: {mean_arr_10k_ms} segundos.")

# %%
time_arr1_20k_ms = tempo_ordenaçao_ms(arr1_20k)
print(f"Tempo do primeiro array de 20k: {time_arr1_20k_ms} segundos.")
time_arr2_20k_ms = tempo_ordenaçao_ms(arr2_20k)
print(f"Tempo do primeiro array de 20k: {time_arr2_20k_ms} segundos.")
time_arr3_20k_ms = tempo_ordenaçao_ms(arr3_20k)
print(f"Tempo do primeiro array de 20k: {time_arr3_20k_ms} segundos.")
time_wc_20k_ms = tempo_ordenaçao_ms(arr_wc_20k)
print(f"Tempo do primeiro array de 20k: {time_wc_20k_ms} segundos.")

# %%
mean_arr_20k_ms = (time_arr1_20k_ms + time_arr2_20k_ms + time_arr3_20k_ms)/3
list_arr_20k_ms = np.array([time_arr1_20k_ms, time_arr2_20k_ms, time_arr3_20k_ms, time_wc_20k_ms, mean_arr_20k_ms])
print(f"Tempo médio de ordenação dos arrays aleatórios de 20k: {mean_arr_20k_ms} segundos.")

# %%
time_arr1_30k_ms = tempo_ordenaçao_ms(arr1_30k)
print(f"Tempo do primeiro array de 30k: {time_arr1_30k_ms} segundos.")
time_arr2_30k_ms = tempo_ordenaçao_ms(arr2_30k)
print(f"Tempo do primeiro array de 30k: {time_arr2_30k_ms} segundos.")
time_arr3_30k_ms = tempo_ordenaçao_ms(arr3_30k)
print(f"Tempo do primeiro array de 30k: {time_arr3_30k_ms} segundos.")
time_wc_30k_ms = tempo_ordenaçao_ms(arr_wc_30k)
print(f"Tempo do primeiro array de 30k: {time_wc_30k_ms} segundos.")

# %%
mean_arr_30k_ms = (time_arr1_30k_ms + time_arr2_30k_ms + time_arr3_30k_ms)/3
list_arr_30k_ms = np.array([time_arr1_30k_ms, time_arr2_30k_ms, time_arr3_30k_ms, time_wc_30k_ms, mean_arr_30k_ms])
print(f"Tempo médio de ordenação dos arrays aleatórios de 30k: {mean_arr_30k_ms} segundos.")

# %%
time_arr1_40k_ms = tempo_ordenaçao_ms(arr1_40k)
print(f"Tempo do primeiro array de 40k: {time_arr1_40k_ms} segundos.")
time_arr2_40k_ms = tempo_ordenaçao_ms(arr2_40k)
print(f"Tempo do primeiro array de 40k: {time_arr2_40k_ms} segundos.")
time_arr3_40k_ms = tempo_ordenaçao_ms(arr3_40k)
print(f"Tempo do primeiro array de 40k: {time_arr3_40k_ms} segundos.")
time_wc_40k_ms = tempo_ordenaçao_ms(arr_wc_40k)
print(f"Tempo do primeiro array de 40k: {time_wc_40k_ms} segundos.")

# %%
mean_arr_40k_ms = (time_arr1_40k_ms + time_arr2_40k_ms + time_arr3_40k_ms)/3
list_arr_40k_ms = np.array([time_arr1_40k_ms, time_arr2_40k_ms, time_arr3_40k_ms, time_wc_40k_ms, mean_arr_40k_ms])
print(f"Tempo médio de ordenação dos arrays aleatórios de 40k: {mean_arr_40k_ms} segundos.")

# %%
time_arr1_50k_ms = tempo_ordenaçao_ms(arr1_50k)
print(f"Tempo do primeiro array de 50k: {time_arr1_50k_ms} segundos.")
time_arr2_50k_ms = tempo_ordenaçao_ms(arr2_50k)
print(f"Tempo do primeiro array de 50k: {time_arr2_50k_ms} segundos.")
time_arr3_50k_ms = tempo_ordenaçao_ms(arr3_50k)
print(f"Tempo do primeiro array de 50k: {time_arr3_50k_ms} segundos.")
time_wc_50k_ms = tempo_ordenaçao_ms(arr_wc_50k)
print(f"Tempo do primeiro array de 50k: {time_wc_50k_ms} segundos.")

# %%
mean_arr_50k_ms = (time_arr1_50k_ms + time_arr2_50k_ms + time_arr3_50k_ms)/3
list_arr_50k_ms = np.array([time_arr1_50k_ms, time_arr2_50k_ms, time_arr3_50k_ms, time_wc_50k_ms, mean_arr_50k_ms])
print(f"Tempo médio de ordenação dos arrays aleatórios de 50k: {mean_arr_50k_ms} segundos.")

# %% [markdown]
# ## 2. Fazendo as listas de tempos e médias do método

# %%
# Definição das variáveis _ms
list_ms = np.array([list_arr_1k_ms, list_arr_5k_ms, list_arr_10k_ms, list_arr_20k_ms,
                    list_arr_30k_ms, list_arr_40k_ms, list_arr_50k_ms])

mean_arr_ms = np.array([mean_arr_1k_ms, mean_arr_5k_ms, mean_arr_10k_ms, mean_arr_20k_ms,
                        mean_arr_30k_ms, mean_arr_40k_ms, mean_arr_50k_ms])

# %% [markdown]
# ## 3. Salvando os Dados

# %%
# Comandos para salvar os arrays _ms
np.save("list_ms", list_ms)
np.save("mean_arr_ms", mean_arr_ms)
