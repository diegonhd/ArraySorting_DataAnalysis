# %%
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
# Definindo a função bubble sort sem lib (obrigatório)
def bubble_sort(lista):
    n = len(lista)
    for i in range(n):
        for j in range(0, n - i - 1):
            if lista[j] > lista[j + 1]:
                lista[j], lista[j + 1] = lista[j + 1], lista[j]
    return lista

# %%
# Definindo a função de retorno do tempo que o array levou a ser ordenado
def tempo_ordenaçao(lista):
    start_time = time.time()
    bubble_sort(lista)
    end_time = time.time()
    total_time = end_time - start_time
    return total_time

# %% [markdown]
# ## Para o caso dos arrays de size = 1k

# %%
# Gerando os 3 arrays aleatórios de cada caso (1k)
arr1_1k = np.random.randint(1,1001,1000)
arr2_1k = np.random.randint(1,1001,1000)
arr3_1k = np.random.randint(1,1001,1000)

# Fazendo um array do pior caso 
arr_wc_1k = arr1_1k[::-1]

# %%
# Pegando o tempo de ordenação dos 4 arrays
time_arr1_1k =  tempo_ordenaçao(arr1_1k)
print("Tempo do primeiro array de 1k:", time_arr1_1k)
time_arr2_1k = tempo_ordenaçao(arr2_1k)
print("Tempo do segundo array de 1k:", time_arr2_1k)
time_arr3_1k = tempo_ordenaçao(arr3_1k)
print("Tempo do terceiro array de 1k:", time_arr3_1k)
time_wc_1k = tempo_ordenaçao(arr_wc_1k)
print("Tempo do pior caso do array de 1k:", time_wc_1k)
# Out:
# Tempo do primeiro array de 1k: 0.19349956512451172
# Tempo do segundo array de 1k: 0.1921851634979248
# Tempo do terceiro array de 1k: 0.1910996437072754
# Tempo do pior caso do array de 1k: 0.272416353225708

# %%
# Fazendo uma média dos 3 casos dos arrays aleatórios
list_arr_1k = np.array([time_arr1_1k, time_arr2_1k, time_arr3_1k])
mean_arr_1k = list_arr_1k.mean()
print("Tempo médio de ordenação dos arrays de 1k:", mean_arr_1k)
# Out:
# Tempo médio de ordenação dos arrays de 1k: 0.1922614574432373

# %% [markdown]
# ## Para os arrays de 5k

# %%
# Gerando os 3 arrays aleatórios de cada caso (1k)
arr1_5k = np.random.randint(1,1001,5000)
arr2_5k = np.random.randint(1,1001,5000)
arr3_5k = np.random.randint(1,1001,5000)

# Fazendo um array do pior caso 
arr_wc_5k = arr1_5k[::-1]

# %%
# Pegando o tempo de ordenação dos 4 arrays
time_arr1_5k =  tempo_ordenaçao(arr1_5k)
print("Tempo do primeiro array de 1k:", time_arr1_5k)
time_arr2_5k = tempo_ordenaçao(arr2_5k)
print("Tempo do segundo array de 1k:", time_arr2_5k)
time_arr3_5k = tempo_ordenaçao(arr3_5k)
print("Tempo do terceiro array de 1k:", time_arr3_5k)
time_wc_5k = tempo_ordenaçao(arr_wc_5k)
print("Tempo do pior caso do array de 1k:", time_wc_5k)
# Out:
# Tempo do primeiro array de 1k: 4.664525747299194
# Tempo do segundo array de 1k: 4.703747749328613
# Tempo do terceiro array de 1k: 4.680361032485962
# Tempo do pior caso do array de 1k: 6.898261785507202

# %%
# Fazendo uma média dos 3 casos dos arrays aleatórios
list_arr_5k = np.array([time_arr1_5k, time_arr2_5k, time_arr3_5k])
mean_arr_5k = list_arr_5k.mean()
print("Tempo médio de ordenação dos arrays de 1k:", mean_arr_5k)
# Out:
# Tempo médio de ordenação dos arrays de 1k: 4.682878176371257

# %% [markdown]
# ## Para os arrays de 10k

# %%
# Gerando os 3 arrays aleatórios (10k)
arr1_10k = np.random.randint(1,1001,10000)
arr2_10k = np.random.randint(1,1001,10000)
arr3_10k = np.random.randint(1,1001,10000)

# Fazendo um array do pior caso 
arr_wc_10k = arr1_10k[::-1]

# %%
# Pegando o tempo de ordenação dos 4 arrays
time_arr1_10k =  tempo_ordenaçao(arr1_10k)
print("Tempo do primeiro array de 1k:", time_arr1_10k)
time_arr2_10k = tempo_ordenaçao(arr2_10k)
print("Tempo do segundo array de 1k:", time_arr2_10k)
time_arr3_10k = tempo_ordenaçao(arr3_10k)
print("Tempo do terceiro array de 1k:", time_arr3_10k)
time_wc_10k = tempo_ordenaçao(arr_wc_10k)
print("Tempo do pior caso do array de 1k:", time_wc_10k)
# Out:
# Tempo do primeiro array de 1k: 19.88411808013916
# Tempo do segundo array de 1k: 18.700676918029785
# Tempo do terceiro array de 1k: 18.62729811668396
# Tempo do pior caso do array de 1k: 27.203893184661865

# %%
# Fazendo uma média dos 3 casos dos arrays aleatórios
list_arr_10k = np.array([time_arr1_10k, time_arr2_10k, time_arr3_10k])
mean_arr_10k = list_arr_10k.mean()
print("Tempo médio de ordenação dos arrays aleatórios de 1k:", mean_arr_10k)
# Out:
# Tempo médio de ordenação dos arrays de 1k: 19.07069770495097

# %% [markdown]
# ## Para os arrays de 50k

# %%
# Gerando os 3 arrays aleatórios (10k)
arr1_50k = np.random.randint(1,1001,50000)
arr2_50k = np.random.randint(1,1001,50000)
arr3_50k = np.random.randint(1,1001,50000)

# Fazendo um array do pior caso 
arr_wc_50k = arr1_50k[::-1]

# %%
# Pegando o tempo de ordenação dos 4 arrays
time_arr1_50k =  tempo_ordenaçao(arr1_50k)
print("Tempo do primeiro array de 1k:", time_arr1_50k)
time_arr2_50k = tempo_ordenaçao(arr2_50k)
print("Tempo do segundo array de 1k:", time_arr2_50k)
time_arr3_50k = tempo_ordenaçao(arr3_50k)
print("Tempo do terceiro array de 1k:", time_arr3_50k)
time_wc_50k = tempo_ordenaçao(arr_wc_50k)
print("Tempo do pior caso do array de 1k:", time_wc_50k)
# Out:
# Tempo do primeiro array de 1k: 469.79470801353455
# Tempo do segundo array de 1k: 470.0382869243622
# Tempo do terceiro array de 1k: 769.5509612560272
# Tempo do pior caso do array de 1k: 4321.976095914841

# %%
# Fazendo uma média dos 3 casos dos arrays aleatórios
list_arr_50k = np.array([time_arr1_50k, time_arr2_50k, time_arr3_50k])
mean_arr_50k = list_arr_50k.mean()
print("Tempo médio de ordenação dos arrays aleatórios de 1k:", mean_arr_50k)
# Out:
# Tempo médio de ordenação dos arrays aleatórios de 1k: 569.7946520646414

# %%
# Salvando o tamanho dos arrays
np.save("arr1_1k", arr1_1k)
np.save("arr1_5k", arr1_5k)
np.save("arr1_10k", arr1_10k)
np.save("arr1_50k", arr1_50k)

# %%
# Salvando os tempos de ordenação
np.save("list_arr_1k", list_arr_1k)
np.save("list_arr_5k", list_arr_5k)
np.save("list_arr_10k", list_arr_10k)
np.save("list_arr_50k", list_arr_50k)

# %%
# Salvando as médias dos tempos dos arrays aleatórios
np.save("mean_arr_1k", mean_arr_1k)
np.save("mean_arr_5k", mean_arr_5k)
np.save("mean_arr_10k", mean_arr_10k)
np.save("mean_arr_50k", mean_arr_50k)

# %%
# Salvando os piores tempos
np.save("arr_wc_1k", arr_wc_1k)
np.save("arr_wc_5k", arr_wc_5k)
np.save("arr_wc_10k", arr_wc_10k)
np.save("arr_wc_50k", arr_wc_50k)
